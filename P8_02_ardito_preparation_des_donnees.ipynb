# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns 
import csv
from pandas_profiling import ProfileReport

# %%
basic=pd.read_csv(r"C:\Users\piard\OneDrive\Documents\Projet 8\DAN-P8-donnees\BasicAndSafelyManagedDrinkingWaterServices.csv")

# %%
mortality=pd.read_csv(r"C:\Users\piard\OneDrive\Documents\Projet 8\DAN-P8-donnees\MortalityRateAttributedToWater.csv")

# %%
politicalstab=pd.read_csv(r"C:\Users\piard\OneDrive\Documents\Projet 8\DAN-P8-donnees\PoliticalStability.csv")

# %%
pop=pd.read_csv(r"C:\Users\piard\OneDrive\Documents\Projet 8\DAN-P8-donnees\Population.csv")

# %%
Régionmonde=pd.read_csv(r"C:\Users\piard\OneDrive\Documents\Projet 8\DAN-P8-donnees\RegionCountry.csv")

# %%
basic
# Out:
#        Year      Country Granularity  \
# 0      2000  Afghanistan       Rural
# 1      2000  Afghanistan       Total
# 2      2000  Afghanistan       Urban
# 3      2000      Albania       Rural
# 4      2000      Albania       Total
# ...     ...          ...         ...
# 10471  2017       Zambia       Total
# 10472  2017       Zambia       Urban
# 10473  2017     Zimbabwe       Rural
# 10474  2017     Zimbabwe       Total
# 10475  2017     Zimbabwe       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 0                                               21.61913
# 1                                               27.77190
# 2                                               49.48745
# 3                                               81.78472
# 4                                               87.86662
# ...                                                  ...
# 10471                                           59.96376
# ...

# %%
mortality[mortality['Country']=='China']
# Out:
#      Year Country Granularity  \
# 102  2016   China      Female
# 103  2016   China        Male
# 104  2016   China       Total
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 102                                            0.65809
# 103                                            0.49931
# 104                                            0.57632
#
#      WASH deaths
# 102          NaN
# 103          NaN
# 104     8134.223

# %%
politicalstab1=politicalstab.drop(columns=['Granularity'])

# %%
chine=politicalstab1[politicalstab1['Country'].str.contains("China")].groupby(['Year']).mean().reset_index()

# %%
chine
# Out:
#     Year  Political_Stability
# 0   2000               0.4375
# 1   2002               0.4575
# 2   2003               0.5375
# 3   2004               0.6800
# 4   2005               0.7000
# 5   2006               0.5750
# 6   2007               0.4025
# 7   2008               0.4900
# 8   2009               0.4250
# 9   2010               0.4275
# 10  2011               0.4775
# 11  2012               0.4975
# 12  2013               0.5025
# 13  2014               0.6525
# 14  2015               0.6550
# 15  2016               0.6500
# 16  2017               0.7225
# 17  2018               0.6600

# %%
chine1=chine.assign(Country='China')[['Country','Year','Political_Stability']]

# %%
chine1
# Out:
#    Country  Year  Political_Stability
# 0    China  2000               0.4375
# 1    China  2002               0.4575
# 2    China  2003               0.5375
# 3    China  2004               0.6800
# 4    China  2005               0.7000
# 5    China  2006               0.5750
# 6    China  2007               0.4025
# 7    China  2008               0.4900
# 8    China  2009               0.4250
# 9    China  2010               0.4275
# 10   China  2011               0.4775
# 11   China  2012               0.4975
# 12   China  2013               0.5025
# 13   China  2014               0.6525
# 14   China  2015               0.6550
# 15   China  2016               0.6500
# 16   China  2017               0.7225
# 17   China  2018               0.6600

# %%
politicalstab2=politicalstab1[~politicalstab1['Country'].str.contains("China")]

# %%
politicalstab3=pd.concat([politicalstab2,chine1],axis=0)

# %%
basic[basic['Country'].str.contains("China")]
# Out:
#        Year Country Granularity  \
# 105    2000   China       Rural
# 106    2000   China       Total
# 107    2000   China       Urban
# 687    2001   China       Rural
# 688    2001   China       Total
# 689    2001   China       Urban
# 1269   2002   China       Rural
# 1270   2002   China       Total
# 1271   2002   China       Urban
# 1851   2003   China       Rural
# 1852   2003   China       Total
# 1853   2003   China       Urban
# 2433   2004   China       Rural
# 2434   2004   China       Total
# 2435   2004   China       Urban
# 3015   2005   China       Rural
# 3016   2005   China       Total
# 3017   2005   China       Urban
# 3597   2006   China       Rural
# 3598   2006   China       Total
# 3599   2006   China       Urban
# 4179   2007   China       Rural
# 4180   2007   China       Total
# 4181   2007   China       Urban
# 4761   2008   China       Rural
# 4762   2008   China       Total
# 4763   2008   China       Urban
# 5343   2009   China       Rural
# ...

# %%
mortality[mortality['Country'].str.contains("China")]
# Out:
#      Year Country Granularity  \
# 102  2016   China      Female
# 103  2016   China        Male
# 104  2016   China       Total
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 102                                            0.65809
# 103                                            0.49931
# 104                                            0.57632
#
#      WASH deaths
# 102          NaN
# 103          NaN
# 104     8134.223

# %%
pop1=pop[~pop['Country'].str.contains("China,")]

# %%
pop1
# Out:
#            Country Granularity  Year  Population
# 0      Afghanistan       Total  2000   20779.953
# 1      Afghanistan        Male  2000   10689.508
# 2      Afghanistan      Female  2000   10090.449
# 3      Afghanistan       Rural  2000   15657.474
# 4      Afghanistan       Urban  2000    4436.282
# ...            ...         ...   ...         ...
# 20909     Zimbabwe       Total  2018   14438.802
# 20910     Zimbabwe        Male  2018    6879.119
# 20911     Zimbabwe      Female  2018    7559.693
# 20912     Zimbabwe       Rural  2018   11465.748
# 20913     Zimbabwe       Urban  2018    5447.513
#
# [20534 rows x 4 columns]

# %%
Régionmonde[Régionmonde['COUNTRY (DISPLAY)'].str.contains("China")]
# Out:
#    REGION (DISPLAY) COUNTRY (DISPLAY)
# 18  Western Pacific             China

# %%
pop1['Population']=pop1['Population'] * 1000
# Out:
# NumExpr defaulting to 8 threads.
# <ipython-input-21-a52a7cc74235>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop1['Population']=pop1['Population'] * 1000

# %%
pop1
# Out:
#            Country Granularity  Year  Population
# 0      Afghanistan       Total  2000  20779953.0
# 1      Afghanistan        Male  2000  10689508.0
# 2      Afghanistan      Female  2000  10090449.0
# 3      Afghanistan       Rural  2000  15657474.0
# 4      Afghanistan       Urban  2000   4436282.0
# ...            ...         ...   ...         ...
# 20909     Zimbabwe       Total  2018  14438802.0
# 20910     Zimbabwe        Male  2018   6879119.0
# 20911     Zimbabwe      Female  2018   7559693.0
# 20912     Zimbabwe       Rural  2018  11465748.0
# 20913     Zimbabwe       Urban  2018   5447513.0
#
# [20534 rows x 4 columns]

# %%
mortality
# Out:
#      Year      Country Granularity  \
# 0    2016  Afghanistan      Female
# 1    2016  Afghanistan        Male
# 2    2016  Afghanistan       Total
# 3    2016      Albania      Female
# 4    2016      Albania        Male
# ..    ...          ...         ...
# 544  2016       Zambia        Male
# 545  2016       Zambia       Total
# 546  2016     Zimbabwe      Female
# 547  2016     Zimbabwe        Male
# 548  2016     Zimbabwe       Total
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 0                                             15.31193
# 1                                             12.61297
# 2                                             13.92067
# 3                                              0.12552
# 4                                              0.20650
# ..                                                 ...
# 544                                           36.61913
# 545                                           34.91273
# ...

# %%
pop3=pd.pivot_table(pop1,index=['Country','Year'],columns='Granularity').reset_index()

# %%
pop3.columns=['Country','Year','PopF','PopM','PopR','PopT','PopU']

# %%
pop3
# Out:
#           Country  Year        PopF        PopM        PopR        PopT  \
# 0     Afghanistan  2000  10090449.0  10689508.0  15657474.0  20779953.0
# 1     Afghanistan  2001  10489238.0  11117754.0  16318324.0  21606988.0
# 2     Afghanistan  2002  10958668.0  11642106.0  17086910.0  22600770.0
# 3     Afghanistan  2003  11466237.0  12214634.0  17909063.0  23680871.0
# 4     Afghanistan  2004  11962963.0  12763726.0  18692107.0  24726684.0
# ...           ...   ...         ...         ...         ...         ...
# 4349     Zimbabwe  2014   7126795.0   6459915.0  10402274.0  13586707.0
# 4350     Zimbabwe  2015   7245864.0   6568778.0  10667966.0  13814629.0
# 4351     Zimbabwe  2016   7356132.0   6674206.0  10934468.0  14030331.0
# 4352     Zimbabwe  2017   7459545.0   6777054.0  11201138.0  14236595.0
# 4353     Zimbabwe  2018   7559693.0   6879119.0  11465748.0  14438802.0
#
#            PopU
# 0     4436282.0
# 1     4648139.0
# 2     4893013.0
# 3     5155788.0
# ...

# %%
basic1=pd.pivot_table(basic,index=['Country','Year'],columns='Granularity').reset_index()

# %%
basic1.columns=['Country','Year','PopbasicR%','PopbasicT%','PopbasicU%','PopsafelyR%','PopsafelyT%','PopsafelyU%']

# %%
basic1
# Out:
#           Country  Year  PopbasicR%  PopbasicT%  PopbasicU%  PopsafelyR%  \
# 0     Afghanistan  2000    21.61913    27.77190    49.48745          NaN
# 1     Afghanistan  2001    21.61913    27.79726    49.48745          NaN
# 2     Afghanistan  2002    23.59988    29.90076    51.90447          NaN
# 3     Afghanistan  2003    25.58063    32.00507    54.32149          NaN
# 4     Afghanistan  2004    27.56138    34.12623    56.73851          NaN
# ...           ...   ...         ...         ...         ...          ...
# 3450     Zimbabwe  2013    52.26732    65.97417    94.24335          NaN
# 3451     Zimbabwe  2014    51.64819    65.47338    94.18200          NaN
# 3452     Zimbabwe  2015    51.03139    64.98583    94.12061          NaN
# 3453     Zimbabwe  2016    50.41692    64.51162    94.05916          NaN
# 3454     Zimbabwe  2017    49.80476    64.05123    93.99767          NaN
#
#       PopsafelyT%  PopsafelyU%
# 0             NaN          NaN
# ...

# %%
basic1[basic1['Year']==2016]['PopsafelyT%'].mean()
# Out:
# 77.93851040816325

# %%
mortality1=pd.pivot_table(mortality,index=['Country','Year'],columns='Granularity').reset_index()

# %%
mortality1.columns=['Country','Year','MortalityrateF','MortalityrateH','MortalityrateT','WASHdeathsT']

# %%
mortality1
# Out:
#                                 Country  Year  MortalityrateF  MortalityrateH  \
# 0                           Afghanistan  2016        15.31193        12.61297
# 1                               Albania  2016         0.12552         0.20650
# 2                               Algeria  2016         2.19890         1.72837
# 3                                Angola  2016        45.15024        52.62506
# 4                   Antigua and Barbuda  2016         0.10419         0.12469
# ..                                  ...   ...             ...             ...
# 178  Venezuela (Bolivarian Republic of)  2016         1.36928         1.41152
# 179                            Viet Nam  2016         1.13807         2.11376
# 180                               Yemen  2016        11.77016         8.66892
# 181                              Zambia  2016        33.23213        36.61913
# 182                            Zimbabwe  2016        22.16388        27.06688
#
#      MortalityrateT  WASHdeathsT
# ...

# %%
pbasic=pop3.merge(basic1,on=['Country','Year'],how='outer')

# %%
p_basic_political=pbasic.merge(politicalstab3,on=['Country','Year'],how='outer')

# %%
p_basic_political
# Out:
#           Country  Year        PopF        PopM        PopR        PopT  \
# 0     Afghanistan  2000  10090449.0  10689508.0  15657474.0  20779953.0
# 1     Afghanistan  2001  10489238.0  11117754.0  16318324.0  21606988.0
# 2     Afghanistan  2002  10958668.0  11642106.0  17086910.0  22600770.0
# 3     Afghanistan  2003  11466237.0  12214634.0  17909063.0  23680871.0
# 4     Afghanistan  2004  11962963.0  12763726.0  18692107.0  24726684.0
# ...           ...   ...         ...         ...         ...         ...
# 4386        Sudan  2007         NaN         NaN         NaN         NaN
# 4387        Sudan  2008         NaN         NaN         NaN         NaN
# 4388        Sudan  2009         NaN         NaN         NaN         NaN
# 4389        Sudan  2010         NaN         NaN         NaN         NaN
# 4390        Sudan  2011         NaN         NaN         NaN         NaN
#
#            PopU  PopbasicR%  PopbasicT%  PopbasicU%  PopsafelyR%  PopsafelyT%  \
# ...

# %%
p_basic_political['Taux de pop urbaine']=p_basic_political['PopU']/p_basic_political['PopT']

# %%
p_basic_political
# Out:
#           Country  Year        PopF        PopM        PopR        PopT  \
# 0     Afghanistan  2000  10090449.0  10689508.0  15657474.0  20779953.0
# 1     Afghanistan  2001  10489238.0  11117754.0  16318324.0  21606988.0
# 2     Afghanistan  2002  10958668.0  11642106.0  17086910.0  22600770.0
# 3     Afghanistan  2003  11466237.0  12214634.0  17909063.0  23680871.0
# 4     Afghanistan  2004  11962963.0  12763726.0  18692107.0  24726684.0
# ...           ...   ...         ...         ...         ...         ...
# 4386        Sudan  2007         NaN         NaN         NaN         NaN
# 4387        Sudan  2008         NaN         NaN         NaN         NaN
# 4388        Sudan  2009         NaN         NaN         NaN         NaN
# 4389        Sudan  2010         NaN         NaN         NaN         NaN
# 4390        Sudan  2011         NaN         NaN         NaN         NaN
#
#            PopU  PopbasicR%  PopbasicT%  PopbasicU%  PopsafelyR%  PopsafelyT%  \
# ...

# %%
p_basic_political_region=p_basic_political.merge(Régionmonde,left_on='Country',right_on='COUNTRY (DISPLAY)',how='outer')

# %%
p_basic_political_region=p_basic_political_region.drop(columns='COUNTRY (DISPLAY)')

# %%
p_basic_political_region
# Out:
#                           Country  Year        PopF        PopM        PopR  \
# 0                     Afghanistan  2000  10090449.0  10689508.0  15657474.0
# 1                     Afghanistan  2001  10489238.0  11117754.0  16318324.0
# 2                     Afghanistan  2002  10958668.0  11642106.0  17086910.0
# 3                     Afghanistan  2003  11466237.0  12214634.0  17909063.0
# 4                     Afghanistan  2004  11962963.0  12763726.0  18692107.0
# ...                           ...   ...         ...         ...         ...
# 4386  Republic of North Macedonia  2013         NaN         NaN         NaN
# 4387  Republic of North Macedonia  2014         NaN         NaN         NaN
# 4388  Republic of North Macedonia  2015         NaN         NaN         NaN
# 4389  Republic of North Macedonia  2016         NaN         NaN         NaN
# 4390  Republic of North Macedonia  2017         NaN         NaN         NaN
#
# ...

# %%
p_basic_political_region_mortality=p_basic_political_region.merge(mortality1,on=['Country','Year'],how='outer')

# %%
p_basic_political_region_mortality
# Out:
#                           Country  Year        PopF        PopM        PopR  \
# 0                     Afghanistan  2000  10090449.0  10689508.0  15657474.0
# 1                     Afghanistan  2001  10489238.0  11117754.0  16318324.0
# 2                     Afghanistan  2002  10958668.0  11642106.0  17086910.0
# 3                     Afghanistan  2003  11466237.0  12214634.0  17909063.0
# 4                     Afghanistan  2004  11962963.0  12763726.0  18692107.0
# ...                           ...   ...         ...         ...         ...
# 4386  Republic of North Macedonia  2013         NaN         NaN         NaN
# 4387  Republic of North Macedonia  2014         NaN         NaN         NaN
# 4388  Republic of North Macedonia  2015         NaN         NaN         NaN
# 4389  Republic of North Macedonia  2016         NaN         NaN         NaN
# 4390  Republic of North Macedonia  2017         NaN         NaN         NaN
#
# ...

# %%
p_basic_political_region_mortality.to_excel('pop_basic_political_region_mortality.xlsx')

# %%
p_basic_political_region_mortality
# Out:
#                           Country  Year        PopF        PopM        PopR  \
# 0                     Afghanistan  2000  10090449.0  10689508.0  15657474.0
# 1                     Afghanistan  2001  10489238.0  11117754.0  16318324.0
# 2                     Afghanistan  2002  10958668.0  11642106.0  17086910.0
# 3                     Afghanistan  2003  11466237.0  12214634.0  17909063.0
# 4                     Afghanistan  2004  11962963.0  12763726.0  18692107.0
# ...                           ...   ...         ...         ...         ...
# 4386  Republic of North Macedonia  2013         NaN         NaN         NaN
# 4387  Republic of North Macedonia  2014         NaN         NaN         NaN
# 4388  Republic of North Macedonia  2015         NaN         NaN         NaN
# 4389  Republic of North Macedonia  2016         NaN         NaN         NaN
# 4390  Republic of North Macedonia  2017         NaN         NaN         NaN
#
# ...
